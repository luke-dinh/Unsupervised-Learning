# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from skimage import data, img_as_float

# %%
cat_image = img_as_float(data.chelsea())

plt.figure(figsize=(20,20))
plt.imshow(cat_image)

# %%
cat_image = cat_image/255.0
cat_image.shape
# Out:
# (300, 451, 3)

# %%
X = cat_image.reshape(-1,3)
X.shape
# Out:
# (135300, 3)

# %%
k_clusters = list(range(1,6))
sse = []

for k in k_clusters:
  km = KMeans(n_clusters=k)
  km.fit(X)
  sse.append(km.inertia_)

plt.figure(figsize=(10,10))
plt.plot(k_clusters, sse, '-o')
plt.xlabel('Number of clusters')
plt.ylabel('Sum of Suqared Error')
plt.show()

# %%
km_new = KMeans(n_clusters=3)
km_new.fit(X)

img_seg = km_new.cluster_centers_

# %%
print(img_seg)
# Out:
# [[0.00225297 0.00165622 0.00121099]
#  [0.00273024 0.00224088 0.00197259]
#  [0.00153266 0.00096247 0.00056602]]

# %%
img_seg = img_seg[km_new.labels_]

# %%
img_seg = img_seg.reshape(cat_image.shape)

# %%
plt.figure(figsize=(20,20))
plt.imshow(img_seg)

# %%
# Silhouette Analysis

from sklearn.metrics import silhouette_samples, silhouette_score

for i, k in enumerate([2,3,4]):
  fig, ax = plt.subplots()
  fig.set_size_inches(18,18)

  km = KMeans(n_clusters=k, random_state = 0, max_iter = 50, n_init=10, verbose=1)
  labels = km.fit_predict(X)
  centroids = km.cluster_centers_
  
  silhouette_val = silhouette_samples(X, labels)

  # Silhouette plot
  y_ticks = []
  y_lower, y_upper = 0, 0
  for i, cluster in enumerate(np.unique(labels)):
    cluster_silhouette_vals = silhouette_val[labels == cluster]
    cluster_silhouette_vals.sort()
    y_upper += len(cluster_silhouette_vals)
    ax.barh(range(y_lower, y_upper), cluster_silhouette_vals, edgecolor='none', height=1)
    ax.text(-0.03, (y_lower + y_upper) / 2, str(i + 1))
    y_lower += len(cluster_silhouette_vals)

  avg_score = np.mean(silhouette_val)
  ax.axvline(avg_score, linestyle='--', linewidth=2, color='green')
  ax.set_yticks([])
  ax.set_xlim([-0.1, 1])
  ax.set_xlabel('Silhouette coefficient values')
  ax.set_ylabel('Cluster labels')
  ax.set_title('Silhouette plot for the various clusters', y=1.02);
# Out:
# Initialization complete
# Iteration 0, inertia 0.14791975747653727.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.15436690179641563.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.13235532862955224.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.22824104022926228.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.12030171910635286.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.2756599228315686.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.11977485109459797.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.11891043308247443.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.2529674827399764.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 0.1479716995252564.
# Iteration 1, inertia 0.11153399704701866.
# Converged at iteration 1: strict convergence.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-79bfe1f284a7> in <module>
#      11   centroids = km.cluster_centers_
#      12
# ---> 13   silhouette_val = silhouette_samples(X, labels)
#      14
#      15   # Silhouette plot
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     227     n_samples = len(labels)
#     228     label_freqs = np.bincount(labels)
# --> 229     check_number_of_labels(len(le.classes_), n_samples)
#     230
#     231     kwds['metric'] = metric
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in check_number_of_labels(n_labels, n_samples)
#      32     """
#      33     if not 1 < n_labels < n_samples:
# ---> 34         raise ValueError("Number of labels is %d. Valid values are 2 "
#      35                          "to n_samples - 1 (inclusive)" % n_labels)
#      36
#
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
